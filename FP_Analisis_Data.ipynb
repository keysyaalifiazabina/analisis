# %% [markdown]
# # Proyek Analisis Data: E-Commerce Dataset
# - **Nama:** Keysya Alifia Zabina
# - **Email:** keysyaalifiazabina@gmail.com
# - **ID Dicoding:** keysya_alifia_zabina

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa saja yang paling laris dan tidak laris dalam penjulan?
# - Kategori produk apa yang paling banyak dibeli?
# - Bagaimana penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir?
# - Bagaimana Demografis Customer yang Dimiliki?
# - Seller kota mana yang menjual produk paling banyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers_df = pd.read_csv("customers_dataset.csv")
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv("geolocation_dataset.csv")
geolocation_df.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv("order_items_dataset.csv")
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments_df = pd.read_csv("order_payments_dataset.csv")
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews_df = pd.read_csv("order_reviews_dataset.csv")
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
orders_df = pd.read_csv("orders_dataset.csv")
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category_df = pd.read_csv("product_category_name_translation.csv")
product_category_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products_df = pd.read_csv("products_dataset.csv")
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv("sellers_dataset.csv")
sellers_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %%
customers_df.info()
customers_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11547 entries, 0 to 11546
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               11547 non-null  object
#  1   customer_unique_id        11547 non-null  object
#  2   customer_zip_code_prefix  11547 non-null  int64
#  3   customer_city             11547 non-null  object
#  4   customer_state            11546 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 451.2+ KB
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              1
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
customers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        customer_zip_code_prefix
# count              11547.000000
# mean               34734.747380
# std                29660.108812
# min                 1005.000000
# 25%                11070.000000
# 50%                24220.000000
# 75%                57795.000000
# max                99980.000000

# %%
geolocation_df.info()
geolocation_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   geolocation_zip_code_prefix  35000 non-null  int64
#  1   geolocation_lat              35000 non-null  float64
#  2   geolocation_lng              35000 non-null  float64
#  3   geolocation_city             35000 non-null  object
#  4   geolocation_state            35000 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.3+ MB
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", geolocation_df.duplicated().sum())
geolocation_df.describe()
# Out:
# Jumlah duplikasi:  15205
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 35000.000000     35000.000000     35000.000000
# mean                   1774.844943       -23.523127       -46.636105
# std                     526.913326         0.039450         0.030063
# min                    1001.000000       -23.883184       -46.786511
# 25%                    1308.000000       -23.557765       -46.656567
# 50%                    1529.000000       -23.531480       -46.642514
# 75%                    2307.000000       -23.488461       -46.620429
# max                    2765.000000       -23.383208       -46.394598

# %% [markdown]
# **Insight:**
#
# - Terdapat adanya duplikasi

# %%
order_items_df.info()
order_items_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83904 entries, 0 to 83903
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             83904 non-null  object
#  1   order_item_id        83904 non-null  int64
#  2   product_id           83904 non-null  object
#  3   seller_id            83903 non-null  object
#  4   shipping_limit_date  83903 non-null  object
#  5   price                83903 non-null  float64
#  6   freight_value        83903 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.5+ MB
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              1
# shipping_limit_date    1
# price                  1
# freight_value          1
# dtype: int64

# %% [markdown]
# **Insight:**
# - Data type shipping_limit_date harusnya datetime

# %%
print("Jumlah duplikasi: ", order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah duplikasi:  0
#        order_item_id         price  freight_value
# count   83904.000000  83903.000000   83903.000000
# mean        1.203089    120.684554      20.000353
# std         0.733530    182.823403      15.768032
# min         1.000000      0.850000       0.000000
# 25%         1.000000     39.900000      13.080000
# 50%         1.000000     74.900000      16.270000
# 75%         1.000000    134.900000      21.150000
# max        21.000000   6735.000000     409.680000

# %%
order_payments_df.info()
order_payments_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", order_payments_df.duplicated().sum())
order_payments_df.describe()
# Out:
# Jumlah duplikasi:  0
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
order_reviews_df.info()
order_reviews_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Terdapat missing value pada review_comment_title dan review_comment_message.
# - Adanya data type yang tidak cocok pada review_creation_date dan review_answer_timestamp

# %%
print("Jumlah duplikasi: ", order_reviews_df.duplicated().sum())
order_reviews_df.describe()
# Out:
# Jumlah duplikasi:  0
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
orders_df.info()
orders_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# ...

# %% [markdown]
# **Insight:**
# - Data type tidak sesuai pada order_approved_at, order_delivered_carrier_date dan order_delivered_customer_date

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah duplikasi:  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %%
product_category_df.info()
product_category_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_category_df.duplicated().sum())
product_category_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
products_df.info()
products_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# ...

# %% [markdown]
# **Insight:**
# - Missing value pada product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, dan product_width_cm

# %%
print("Jumlah duplikasi: ", products_df.duplicated().sum())
products_df.describe()
# Out:
# Jumlah duplikasi:  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %%
sellers_df.info()
sellers_df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
print("Jumlah duplikasi: ", sellers_df.duplicated().sum())
sellers_df.describe()
# Out:
# Jumlah duplikasi:  0
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Cleaning geolocation yang terdapat adanya duplicate, dengan drop duplicate

# %%
geolocation_df.drop_duplicates(inplace=True)

# %%
geolocation_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Mengubah data type untuk shipping_limit_date menjadi datetime

# %%
datetime_columns = ["shipping_limit_date"]

for column in datetime_columns:
  order_items_df[column] = pd.to_datetime(order_items_df[column])

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83904 entries, 0 to 83903
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_id             83904 non-null  object
#  1   order_item_id        83904 non-null  int64
#  2   product_id           83904 non-null  object
#  3   seller_id            83903 non-null  object
#  4   shipping_limit_date  83903 non-null  datetime64[ns]
#  5   price                83903 non-null  float64
#  6   freight_value        83903 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# Menangani missing value pada review_comment_title dan review_comment_message

# %%
order_reviews_df[order_reviews_df.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %%
order_reviews_df[order_reviews_df.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %%
order_reviews_df.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
order_reviews_df.review_comment_message.value_counts()
# Out:
# review_comment_message
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %% [markdown]
# Karena keduanya memiliki arti yang sama yaitu menambahkan komentar terhadap feedback, oleh karena itu replace missing value dengan "No Review Comment"

# %%
order_reviews_df.fillna(value="No Review Comment", inplace=True)

# %%
order_reviews_df.isna().sum()
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %% [markdown]
# Mengganti data type review_creation_date dan review_answer_timestamp

# %%
datetime_columns = ['review_creation_date', 'review_answer_timestamp']

for column in datetime_columns:
  order_reviews_df[column] = pd.to_datetime(order_reviews_df[column])

# %%
order_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  object
#  4   review_comment_message   99224 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# Mengganti data type pada orders

# %%
datetime_columns=['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'
]
for columns in datetime_columns:
    orders_df[columns]=pd.to_datetime(orders_df[columns])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# Langkah selanjutnya ialah menangani missing value pada product. Disini kita bisa menggunakan dropping untuk menghapus data yang dinilai tidak terlalu penting. Disini kita akan drop beberapa data yakni product_name_lenght dan product_description_lenght.

# %%
drop_coloumn = ['product_name_lenght', 'product_description_lenght']
products_df.drop(drop_coloumn, axis= 1, inplace= True)

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32341 non-null  object
#  2   product_photos_qty     32341 non-null  float64
#  3   product_weight_g       32949 non-null  float64
#  4   product_length_cm      32949 non-null  float64
#  5   product_height_cm      32949 non-null  float64
#  6   product_width_cm       32949 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# Selanjutnya kita mengisi nilai missing value, disini masih terdapat adanya missing value.

# %%
products_df[products_df.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_photos_qty  product_weight_g  product_length_cm  \
# 105                   NaN             650.0               17.0
# 128                   NaN             300.0               16.0
# ...

# %% [markdown]
# Mengganti nilai missing value pada product_category_name dengan modus/nilai yang sering muncul.

# %%
products_df['product_category_name'].fillna(products_df['product_category_name'].mode()[0], inplace=True)
# Out:
# <ipython-input-53-518f44aaf083>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df['product_category_name'].fillna(products_df['product_category_name'].mode()[0], inplace=True)

# %% [markdown]
# Mengganti nilai product_photos_qty dengan mean/rata-rata.

# %%
products_df["product_photos_qty"].fillna(value=products_df["product_photos_qty"].mean(), inplace=True)
# Out:
# <ipython-input-54-1972ba17e265>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df["product_photos_qty"].fillna(value=products_df["product_photos_qty"].mean(), inplace=True)

# %% [markdown]
# Mengganti nilai product_weight_g dengan mean/rata-rata, mengganti nilai product_length_cm, product_height_cm dan product_width_cm dengan median/nilai tengah.

# %%
products_df["product_weight_g"].fillna(value=products_df["product_weight_g"].mean(), inplace=True)
products_df["product_length_cm"].fillna(value=products_df["product_length_cm"].median(), inplace=True)
products_df["product_height_cm"].fillna(value=products_df["product_height_cm"].median(), inplace=True)
products_df["product_width_cm"].fillna(value=products_df["product_width_cm"].median(), inplace=True)
# Out:
# <ipython-input-55-98fac7bddbc3>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   products_df["product_weight_g"].fillna(value=products_df["product_weight_g"].mean(), inplace=True)
# <ipython-input-55-98fac7bddbc3>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32951 non-null  object
#  2   product_photos_qty     32951 non-null  float64
#  3   product_weight_g       32951 non-null  float64
#  4   product_length_cm      32951 non-null  float64
#  5   product_height_cm      32951 non-null  float64
#  6   product_width_cm       32951 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore customers_df

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              11547                             11547
# unique                             11547                             11496
# top     06b8999e2fba1a1fbc88172c00ba8bc7  3e43e6105506432c953e165fb2acf44c
# freq                                   1                                 4
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo            1847
# rio de janeiro        823
# belo horizonte        340
# brasilia              229
# curitiba              171
#                      ...
# itapejara d'oeste       1
# itapirapua              1
# itapiuna                1
# itapoa                  1
# zortea                  1
# Name: customer_id, Length: 1719, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat demografi customer berdasarkan kota (city).

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    4875
# RJ    1538
# MG    1376
# RS     610
# PR     600
# SC     399
# BA     368
# ES     240
# GO     234
# DF     231
# PE     185
# CE     146
# MT     119
# PA     118
# MA      82
# MS      81
# PB      51
# RN      51
# PI      49
# AL      47
# TO      36
# SE      34
# RO      29
# AM      21
# AP      10
# AC       9
# RR       7
# Name: customer_id, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat demografi customer berdasarkan negara.

# %% [markdown]
# ### Explore order_item_df

# %%
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items_df.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                              83904   83904.000000
# unique                             73399            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.203089
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
# std                                  NaN       0.733530
#
#                               product_id                         seller_id  \
# count                              83904                             83903
# unique                             27505                              2913
# ...

# %%
order_items_df.groupby(by="price").order_id.nunique().sort_values(ascending=False)
# Out:
# price
# 59.90      1569
# 69.90      1379
# 49.90      1231
# 89.90      1046
# 99.90       961
#            ...
# 216.79        1
# 216.90        1
# 216.99        1
# 217.01        1
# 6735.00       1
# Name: order_id, Length: 5240, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat harga order

# %% [markdown]
# Explore order_payments_df

# %%
order_payments_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments_df.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %%
order_payments_df.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# **Insight:**
# - melihat payment_type yang digunakan dalam order

# %%
order_payments_df.groupby(by="payment_type").agg({
    "order_id" : "nunique",
    "payment_value" : ["max", "min", "mean"]
})
# Out:
#              order_id payment_value
#               nunique           max    min        mean
# payment_type
# boleto          19784       7274.88  11.62  145.034435
# credit_card     76505      13664.08   0.01  163.319021
# debit_card       1528       4445.50  13.38  142.570170
# not_defined         3          0.00   0.00    0.000000
# voucher          3866       3184.34   0.00   65.703354

# %% [markdown]
# **Insight:**
# - Untuk mengetahui nilai max, min dan mean dari nilai pembelian (payment_value)

# %% [markdown]
# ### Explore order_reviews_df

# %%
order_reviews_df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4    No Review Comment
# 1             5    No Review Comment
# 2             5    No Review Comment
# 3             5    No Review Comment
# 4             5    No Review Comment
#
#                               review_comment_message review_creation_date  \
# 0                                  No Review Comment           2018-01-18
# 1                                  No Review Comment           2018-03-10
# 2                                  No Review Comment           2018-02-17
# ...

# %%
order_reviews_df.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %% [markdown]
# ### Explore orders_df

# %%
delivery_time = orders_df["order_delivered_customer_date"] - orders_df["order_delivered_carrier_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 88691  4cd0392f4d2e88d71f9b8a2283806f53  c09c310fa27c644ae4c7b02b09877028
# 20196  8908ad12ebc283352dc07bb7040ba653  2420d2f9ac4a8263a87cc41dcfad471a
# 39252  a5507507d82c1fb664405882ed065af0  1b304cdb65a252be98ec533eac75bbf2
# 85027  5a6879f3d732e716425f7ae07f217d1f  08de2bfdaeaa2ab216ba4a874bf9a4c0
# 71192  bfa80c640c89b8b47f3c864e6de67509  c334c7c2376bea0710476a797ec92388
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 88691    delivered      2018-01-24 18:19:05 2018-01-25 02:38:11
# 20196    delivered      2018-02-15 09:01:59 2018-02-15 09:15:35
# 39252    delivered      2017-08-29 11:34:11 2017-08-30 11:44:33
# 85027    delivered      2017-11-16 15:07:06 2017-11-16 15:15:39
# 71192    delivered      2017-12-23 22:38:14 2017-12-23 22:50:22
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 88691          2018-01-25 22:38:55           2018-01-29 22:53:06
# ...

# %%
orders_df.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
#        order_status       order_purchase_timestamp  \
# ...

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#                            customer_id                customer_unique_id  \
# 5293  d57a120a63ef1c58d8704dbf52553318  67c069b1347ff0bfea48b5035a0153da
# 2364  5a354ceb0ee403f36eead5e33253730e  253d899ff7a011b26c16ac66cdca07de
# 9941  fce904facc2ae9feb164ae30cd7e9a0b  28c1bc12ebbbf90449b82276058cc6e1
# 1596  70e2350198c11f4b50dee6ab81464c98  ef309784561fed416ff25e05ddfe495e
# 4830  db1bc36fe2a1a9eac6ccda33e5fba2a2  eb5eff354c6b7726ab464ec04c97b12a
#
#       customer_zip_code_prefix          customer_city customer_state  status
# 5293                     58280             mamanguape             PB  Active
# 2364                      8253              sao paulo             SP  Active
# 9941                     14807             araraquara             SP  Active
# 1596                     15085  sao jose do rio preto             SP  Active
# 4830                     40330               salvador             BA  Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active    11547
# Name: customer_id, dtype: int64

# %% [markdown]
# **Insight:**
# - menampilkan jumlah status active customer

# %% [markdown]
# ### Explore product_category_df

# %%
product_category_df.describe(include="all")
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
product_category_df.sample(5)
# Out:
#        product_category_name product_category_name_english
# 61                    musica                         music
# 13  tablets_impressao_imagem        tablets_printing_image
# 30         moveis_escritorio              office_furniture
# 64         cds_dvds_musicais             cds_dvds_musicals
# 60                la_cuisine                    la_cuisine

# %% [markdown]
# ### Explore products_df

# %%
products_df.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32951
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3639
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_photos_qty  product_weight_g  product_length_cm  \
# count         32951.000000      32951.000000       32951.000000
# unique                 NaN               NaN                NaN
# ...

# %%
products_df.sample(5)
# Out:
#                              product_id product_category_name  \
# 6663   e1d6e56531bd9c3dfad4f905f81072c7       cama_mesa_banho
# 527    4d777d8c652076edf63299034cc4c599       cama_mesa_banho
# 29671  1d24c180dcf6365fe1f3fc14c0cc589a       cama_mesa_banho
# 24907  bbdef93b1bffe87d66bc97697e58c1ad       cama_mesa_banho
# 20238  d4b65aedaa1a847abd993dced5ed2e30                 bebes
#
#        product_photos_qty  product_weight_g  product_length_cm  \
# 6663             1.000000            1400.0               46.0
# 527              3.000000             950.0               26.0
# 29671            1.000000            1425.0               43.0
# 24907            2.188986            1000.0               18.0
# 20238            2.000000             500.0               25.0
#
#        product_height_cm  product_width_cm
# 6663                 2.0              36.0
# 527                 15.0              19.0
# 29671               10.0              33.0
# ...

# %%
products_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  3639
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# casa_conforto_2                     5
# fashion_roupa_infanto_juvenil       5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_id, Length: 73, dtype: int64

# %% [markdown]
# **Insight:**
# - Menampilkan product kategory terbanyak

# %% [markdown]
# ### Explore sellers_df

# %%
sellers_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %%
sellers_df.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Merge customers_df dan orders_df

# %%
orders_customers_df = pd.merge(
    left=customers_df,
    right=orders_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#     customer_city  order_id
# 0       sao paulo      1847
# 1  rio de janeiro       823
# 2  belo horizonte       340
# 3        brasilia       229
# 4        curitiba       171
# 5    porto alegre       157
# 6        campinas       152
# 7       guarulhos       137
# 8        salvador       127
# 9         niteroi       113

# %% [markdown]
# **Insight**
# - Melihat kota dari customer

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   customer_state  order_id
# 0             SP      4875
# 1             RJ      1538
# 2             MG      1376
# 3             RS       610
# 4             PR       600
# 5             SC       399
# 6             BA       368
# 7             ES       240
# 8             GO       234
# 9             DF       231

# %% [markdown]
# **Insight**
# - Melihat negara dari customer

# %%
orders_customers_df.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#   order_status  order_id
# 0    delivered     11199
# 1      shipped       140
# 2     canceled        73
# 3  unavailable        67
# 4     invoiced        34
# 5   processing        33
# 6     approved         1

# %% [markdown]
# **Insight**
# - Melihat order status customer

# %%
orders_customers_df.groupby(by="delivery_time").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#    delivery_time  order_id
# 0            7.0      1064
# 1            6.0      1042
# 2            1.0       954
# 3            5.0       828
# 4            3.0       816
# 5            8.0       800
# 6            4.0       725
# 7            2.0       572
# 8            9.0       548
# 9           10.0       444

# %% [markdown]
# ### Merge order_items_df dan sellers_df

# %%
seller_items_df = pd.merge(
    left=order_items_df,
    right=sellers_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
seller_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                 27277.0
# 1 2017-05-03 11:05:13  239.90          19.93                  3471.0
# ...

# %%
seller_items_df.groupby(by="price").seller_id.nunique().sort_values(ascending=False)
# Out:
# price
# 39.90      234
# 59.90      229
# 69.90      218
# 29.90      213
# 49.90      212
#           ...
# 99.40        1
# 99.56        1
# 99.60        1
# 99.73        1
# 6735.00      1
# Name: seller_id, Length: 5240, dtype: int64

# %% [markdown]
# **Insight:**
# - melihat harga yang paling mahal berdasarkan penjualan

# %%
seller_items_df.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo              655
# curitiba               121
# rio de janeiro          90
# belo horizonte          64
# guarulhos               49
#                       ...
# japira                   1
# jales                    1
# jaciara                  1
# jacarei / sao paulo      1
# xaxim                    1
# Name: seller_id, Length: 583, dtype: int64

# %%
seller_items_df.groupby(by=["price", "seller_city"]).seller_id.nunique().sort_values(ascending=False)
# Out:
# price   seller_city
# 39.9    sao paulo      57
# 59.9    sao paulo      54
# 19.9    sao paulo      53
# 29.9    sao paulo      47
# 69.9    sao paulo      46
#                        ..
# 68.0    itatiba         1
#         jaboticabal     1
#         maringa         1
#         maua            1
# 6735.0  sao paulo       1
# Name: seller_id, Length: 17946, dtype: int64

# %% [markdown]
# ### Merge order_reviews dan order_payments

# %%
order_revpay_df = pd.merge(
    left=order_payments_df,
    right=order_reviews_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_revpay_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
order_revpay_df.groupby(by=["payment_type", "payment_value"]).order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type  payment_value
# voucher       50.00            242
#               100.00           233
# credit_card   77.57            182
# voucher       20.00            147
# credit_card   73.34            115
#                               ...
#               84.11              1
#               83.92              1
#               83.91              1
#               83.74              1
#               130.96             1
# Name: order_id, Length: 40963, dtype: int64

# %%
order_revpay_df.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max", "mean"]
})
# Out:
#              order_id payment_value
#               nunique           min       max        mean
# payment_type
# boleto          19784         11.62   7274.88  144.986413
# credit_card     76505          0.01  13664.08  163.140977
# debit_card       1528         13.38   4445.50  142.396569
# not_defined         3          0.00      0.00    0.000000
# voucher          3866          0.00   3184.34   65.499655

# %% [markdown]
# **Insight:**
# - Melihat payment tipe serta nilai min max dan mean dari setiap payment tipe

# %%
order_revpay_df.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %% [markdown]
# **Insight:**
# - Melihat pembayaran atau transaksi yang paling besar

# %% [markdown]
#  ### Merge orders_customer_df dan order_revpay_df

# %%
product_df = pd.merge(
    left=product_category_df,
    right=products_df,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_df.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id  product_photos_qty  product_weight_g  \
# 0  e3e020af31d4d89d2602272b315c3f6e                 3.0              75.0
# 1  c5d8079278e912d7e3b6beb48ecb56e8                 1.0            1300.0
# 2  36555a2f528d7b2a255c504191445d39                 1.0            1467.0
# 3  e586ebb6022265ae1eea38f46ffe3ead                 3.0            1050.0
# 4  75b4372e69a42f8ae1d908c076f547b2                 1.0             938.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               21.0                7.0              13.0
# 1               19.0               28.0              17.0
# ...

# %%
product_df.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name
# cama_mesa_banho                  3639
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# tablets_impressao_imagem            9
# casa_conforto_2                     5
# fashion_roupa_infanto_juvenil       5
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat nama kategori produk

# %%
product_df.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               3639
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# tablets_printing_image          9
# home_comfort_2                  5
# fashion_childrens_clothes       5
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat nama kategori produk berdasakan bahasa Inggris

# %%
product_df.groupby(by=["product_category_name", "product_category_name_english"]).product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name          product_category_name_english
# cama_mesa_banho                bed_bath_table                   3639
# esporte_lazer                  sports_leisure                   2867
# moveis_decoracao               furniture_decor                  2657
# beleza_saude                   health_beauty                    2444
# utilidades_domesticas          housewares                       2335
#                                                                 ...
# tablets_impressao_imagem       tablets_printing_image              9
# casa_conforto_2                home_comfort_2                      5
# fashion_roupa_infanto_juvenil  fashion_childrens_clothes           5
# seguros_e_servicos             security_and_services               2
# cds_dvds_musicais              cds_dvds_musicals                   1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# **Insight:**
# - Melihat nama kategori produk dan terjemahannya ke bahasa inggris

# %% [markdown]
# ### Merge 4 data

# %% [markdown]
# Merge orders_customers_df dan order_revpay_df

# %%
customers_orders_df = pd.merge(
    left = orders_customers_df,
    right = order_revpay_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
customers_orders_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Merge seller_item_df dan product_df

# %%
seller_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                 27277.0
# 1 2017-05-03 11:05:13  239.90          19.93                  3471.0
# ...

# %%
products_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty  product_weight_g  product_length_cm  product_height_cm  \
# 0                 1.0             225.0               16.0               10.0
# 1                 1.0            1000.0               30.0               18.0
# 2                 1.0             154.0               18.0                9.0
# 3                 1.0             371.0               26.0                4.0
# 4                 4.0             625.0               20.0               17.0
#
#    product_width_cm
# 0              14.0
# 1              20.0
# 2              15.0
# 3              26.0
# 4              13.0

# %%
seller_df = pd.merge(
    left=seller_items_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
seller_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                 27277.0
# 1 2017-05-03 11:05:13  239.90          19.93                  3471.0
# ...

# %% [markdown]
# ### Merge all_df

# %%
all_df = pd.merge(
    left=customers_orders_df,
    right=seller_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  status  \
# 0                     14409                 franca             SP  Active
# 1                      9790  sao bernardo do campo             SP  Active
# 2                      1151              sao paulo             SP  Active
# 3                      8775        mogi das cruzes             SP  Active
# 4                     13056               campinas             SP  Active
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# **Insight:**
# - Menggabungkan seluruh merge

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13352 entries, 0 to 13351
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    13352 non-null  object
#  1   customer_unique_id             13352 non-null  object
#  2   customer_zip_code_prefix       13352 non-null  int64
#  3   customer_city                  13352 non-null  object
#  4   customer_state                 13351 non-null  object
#  5   status                         13352 non-null  object
#  6   order_id                       13352 non-null  object
#  7   order_status                   13352 non-null  object
#  8   order_purchase_timestamp       13352 non-null  datetime64[ns]
#  9   order_approved_at              13331 non-null  datetime64[ns]
#  10  order_delivered_carrier_date   13120 non-null  datetime64[ns]
#  11  order_delivered_customer_date  12958 non-null  datetime64[ns]
# ...

# %%
all_df.groupby(by=["customer_state", "product_category_name_english"]).agg({
    "price": "sum",
    "payment_value": "sum"
})
all_df.groupby(by=["customer_city", "product_category_name_english"]).agg({
    "price": "sum",
    "payment_value": "sum"
})
# Out:
#                                               price  payment_value
# customer_city product_category_name_english
# abaete        bed_bath_table                  36.90          50.27
# abaetetuba    garden_tools                    49.90         114.70
#               sports_leisure                 134.99         203.08
# abatia        telephony                       27.99          43.09
# abdon batista bed_bath_table                 125.40         313.40
# ...                                             ...            ...
# xanxere       sports_leisure                 104.34         286.04
#               telephony                       24.99          43.27
# xaxim         pet_shop                        94.90         118.71
# ze doca       musical_instruments            359.00         408.04
# zortea        computers_accessories           69.90          90.88
#
# [4549 rows x 2 columns]

# %% [markdown]
# **Insight:**
# - Mengetahui Harga dan payment value di setiap kota.

# %%
all_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              13352                             13352
# unique                             11547                             11496
# top     eed931d3a5222a9a511d18be7fd2a5ba  24f12460aad399ba18f4ed2c2fbab65d
# freq                                  19                                19
# mean                                 NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
# std                                  NaN                               NaN
#
# ...

# %%
all_df.to_csv('all_df.csv', index=False)

# %%
all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13352 entries, 0 to 13351
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    13352 non-null  object
#  1   customer_unique_id             13352 non-null  object
#  2   customer_zip_code_prefix       13352 non-null  int64
#  3   customer_city                  13352 non-null  object
#  4   customer_state                 13351 non-null  object
#  5   status                         13352 non-null  object
#  6   order_id                       13352 non-null  object
#  7   order_status                   13352 non-null  object
#  8   order_purchase_timestamp       13352 non-null  datetime64[ns]
#  9   order_approved_at              13331 non-null  datetime64[ns]
#  10  order_delivered_carrier_date   13120 non-null  datetime64[ns]
#  11  order_delivered_customer_date  12958 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Produk apa saja yang paling laris dan tidak laris dalam penjulan?

# %%
sum_orders_df = all_df.groupby("product_category_name_english")["product_id"].count().reset_index()
sum_orders_df = sum_orders_df.rename(columns={"product_id": "products"})
sum_orders_df = sum_orders_df.sort_values(by="products", ascending=False)

sum_orders_df.head()
# Out:
#    product_category_name_english  products
# 6                 bed_bath_table      1145
# 41                 health_beauty       875
# 37               furniture_decor       755
# 61                sports_leisure       732
# 14         computers_accessories       720

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ["#624E88", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(x="products", y="product_category_name_english", data=sum_orders_df.sort_values(by="products", ascending=False).head(5), palette=colors, ax=ax[0]
)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Produk Paling Laris", loc="center", fontsize=15)
ax[0].tick_params(axis='y', labelsize=12)

sns.barplot(x="products", y="product_category_name_english", data=sum_orders_df.sort_values(by="products").head(5), palette=colors, ax=ax[1]
)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Produk Tidak Laris", loc="center", fontsize=18)
ax[1].tick_params(axis='y', labelsize=15)

plt.suptitle("Produk Laris dan Tidak Laris E-Commerce", fontsize=20)
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
# Out:
# <ipython-input-110-8180ddd3e813>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="products", y="product_category_name_english", data=sum_orders_df.sort_values(by="products", ascending=False).head(5), palette=colors, ax=ax[0]
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %% [markdown]
# **Insight:**
# - Dari bar diatas menandakan bahwa bed_bath_table adalah produk paling laris dalam penjualan ini.
# - Sebaliknya security_and_services adalah produk yang tidak laris. Hal ini dipengaruhi oleh penjualan yang didapatkan.

# %% [markdown]
# ### Kategori produk apa yang paling banyak dibeli?

# %%
most_product = all_df.groupby('product_category_name_english').aggregate({'order_id': 'count'}).rename(columns={"order_id": "order_count"}).sort_values(by="order_count", ascending=False).reset_index()
most_product.head()
# Out:
#   product_category_name_english  order_count
# 0                bed_bath_table         1145
# 1                 health_beauty          875
# 2               furniture_decor          755
# 3                sports_leisure          732
# 4         computers_accessories          720

# %%
sns.barplot(y="product_category_name_english", x="order_count",data=most_product[:10],color="#624E88")
plt.ylabel("Produk Kategori")
plt.xlabel("Total Order")
plt.title("Kategori Produk yang Sering Dibeli")
plt.xticks(rotation="horizontal")
plt.show()

# %% [markdown]
# **Insight:**
# - Grafik diatas menampilkan 10 most produk yang dibeli customer.
# - Produk yang paling banyak dibeli adalah bed_bath_table dengan 12000 lebih.

# %% [markdown]
# ### Bagaimana penjualan dan Revenue Produk dalam beberapa bulan terakhir?

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_approved_at').agg({
    "order_id": "nunique",
    "payment_value" : "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%B')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
# <ipython-input-113-d0fdbcd5bbf7>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_orders_df = all_df.resample(rule='M', on='order_approved_at').agg({
#   order_approved_at  order_count   revenue
# 0           October           41   8936.76
# 1          November            0      0.00
# 2          December            0      0.00
# 3           January           74  25848.52
# 4          February          212  38169.57

# %%
monthly_orders_df = monthly_orders_df.sort_values("order_count").drop_duplicates("order_approved_at", keep="last")
print(monthly_orders_df)
# Out:
#    order_approved_at  order_count    revenue
# 11         September          484   87475.92
# 12           October          535  205330.08
# 14          December          685  113669.45
# 21              July          703  148670.36
# 20              June          736  130992.85
# 18             April          743  143097.67
# 16          February          762  129244.61
# 22            August          775  133554.48
# 15           January          807  148848.88
# 13          November          820  175650.44
# 19               May          838  163050.44
# 17             March          875  172415.80

# %%
month_mapping = {
    "January": 1, "February": 2, "March": 3, "April": 4, "May": 5, "June": 6, "July": 7, "August": 8, "September": 9, "October": 10, "November": 11, "December": 12
}

monthly_orders_df["month_numeric"] = monthly_orders_df["order_approved_at"].map(month_mapping)
monthly_orders_df.sort_values("month_numeric", inplace=True)
monthly_orders_df.drop("month_numeric", axis=1, inplace=True)

plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["order_approved_at"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#624E88"
)
plt.title("Total Pesanan per Bulan", loc="center", fontsize=20)
plt.xlabel("Bulan")
plt.ylabel("Pesanan")
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# **Insight:**
# - Order paling banyak adalah dibulan November
# - Order yang mengalami penurunan terjadi di bulan september dan oktober.
# - Bulan awal cukup stabil namun, diakhir menurun.

# %%
plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["order_approved_at"], monthly_orders_df["revenue"], marker='o', linewidth=2, color="#624E88"
)
plt.title("Total Revenue per Bulan", loc="center", fontsize=20)
plt.xlabel("Bulan")
plt.ylabel("Revenue")
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# **Insight:**
# - Revenue terendah ada pada bulan september, disisi lain ada penurunan revenue pada bulan oktober dan desember.
# - Untuk revenue tertinggi ada pada bulan November.
# - Hasil revenue akan bergantung pada hasil order setiap bulan.

# %% [markdown]
# ### Bagaimana Demografis Customer yang Dimiliki?

# %%
bystate_df = all_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df = bystate_df.sort_values(by='customer_count', ascending=False)
bystate_df.head()
# Out:
#    customer_state  customer_count
# 25             SP            4875
# 18             RJ            1538
# 10             MG            1376
# 22             RS             610
# 17             PR             600

# %%
plt.figure(figsize=(14, 7))
most_customer_state = bystate_df.loc[bystate_df['customer_count'].idxmax(), 'customer_state']
palette = ["#624E88" if state == most_customer_state else "#E5D9F2" for state in bystate_df['customer_state']]

sns.barplot(x="customer_count", y="customer_state", data=bystate_df, palette=palette)
plt.title("Jumlah Customer berdasarkan Negara Bagian", loc="center", fontsize=15)
plt.ylabel("Negara")
plt.xlabel("Jumlah Customer")
plt.tick_params(axis='y', labelsize=10)
plt.show()
# Out:
# <ipython-input-119-a197252cb3be>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="customer_count", y="customer_state", data=bystate_df, palette=palette)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - SP adalah negara bagian yang memiliki paling banyak customer dengan lebih dari 41746.

# %%
bycity_df = all_df['customer_city'].value_counts().head(10)
most_customer_city = bycity_df.idxmax()
bycity_df = bycity_df.sort_values(ascending=False)
bycity_df.head()
# Out:
# customer_city
# sao paulo         2140
# rio de janeiro     952
# belo horizonte     394
# brasilia           256
# curitiba           214
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=bycity_df.index, y=bycity_df.values,
            palette=["#624E88" if city == most_customer_city else "#E5D9F2" for city in bycity_df.index])

plt.title("Jumlah Customer berdasarkan Kota", loc="center", fontsize=15)
plt.xlabel("Kota")
plt.ylabel("Jumlah Customer")
plt.xticks(rotation=30, fontsize=10)
plt.show()
# Out:
# <ipython-input-121-aed9f59d330c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=bycity_df.index, y=bycity_df.values,
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Sao Paulo adalah kota yang memiliki paling banyak customer dengan jumlah 18875.

# %% [markdown]
# ### Seller kota mana yang menjual produk paling banyak?

# %%
most_seller = all_df.groupby('seller_city').aggregate({'order_id':'count'}).rename(columns={'order_id':'order_count'}).sort_values(by='order_count',ascending=False).reset_index()
most_seller.head()
# Out:
#              seller_city  order_count
# 0              sao paulo         2502
# 1               ibitinga          673
# 2            santo andre          263
# 3               curitiba          246
# 4  sao jose do rio preto          234

# %%
top_sellers = all_df['seller_city'].value_counts()[:5]

plt.figure(figsize=(18, 6))
colors = ["#624E88", "#E5D9F2", "#E5D9F2", "#E5D9F2", "#E5D9F2"]
ax = sns.barplot(x=top_sellers.index, y=top_sellers.values, palette=colors)

ax.set_title("Kota dengan sellers terbanyak")
plt.xlabel("Kota")
plt.ylabel("Jumlah Sellers(penjualan)")
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)

plt.show()
# Out:
# <ipython-input-123-da5e2bf361e0>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_sellers.index, y=top_sellers.values, palette=colors)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Seller di kota Sao Paulo adalah yang terbanyak dalam menjual produk dengan jumlah 29293.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
# Mengonversi ke datetime
orders_df['order_approved_at'] = pd.to_datetime(orders_df['order_approved_at'], errors='coerce')
orders_df = orders_df.dropna(subset=['order_approved_at'])

#Nilai RFM
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_approved_at": "max",
    "order_id": "nunique",
    "payment_value": "sum"
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# RFM day
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_approved_at"].dt.date.max()
rfm_df = rfm_df.dropna(subset=["max_order_timestamp"])
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
# <ipython-input-126-4db730d4494d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
# <ipython-input-126-4db730d4494d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
#                         customer_id  frequency  monetary  recency
# 0  001051abfcfdbed9f87b4266213a5df1          1     65.20       96
# 1  0013280441d86a4f7a8006efdaf1b0fe          1    162.15      238
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#624E88", "#624E88", "#624E88", "#624E88", "#624E88"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel("customer_id")
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis='x', labelsize=15)
ax[0].set_xticklabels([])

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel("customer_id")
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
ax[1].set_xticklabels([])

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel("customer_id")
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
ax[2].set_xticklabels([])

plt.suptitle("Best Customer Based on RFM Parameters", fontsize=20)
plt.show()
# Out:
# <ipython-input-136-d07bbc7796dc>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Visualisasi diatas akan menggambarkan bahwa customer yang melakukan transaksi.
# - Kita bisa melihat terakhir kali customer melakukan transaksi melalui tabel By Recency(days).
# - Mengetahui seberapa sering pelanggan melakukan transaksi melalui tabel ny Frequency.
# - Mengetahui pendapatan atau revenue yang didapat dari customer.
# -Informasi ini akan digunakan untuk evaluasi dalam pengembangan e-commerce.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Produk apa saja yang paling laris dan tidak laris dalam penjulan?

# %% [markdown]
# Dalam visualisasi yang telah digambarkan, produk yang paling laris adalah beld_bath_table dengan penjualan sebanyak 12000, sedangkan untuk produk yang tidak laris atau kurang laris adalah security_and_services yang bahkan penjulaannya kurang dari 5, namun mengingat bahwa dataset ini terdiri dari ribuan bahkan puluhan ribu produk alangkah sebaiknya untuk e-commerce lebih gencar dalam mempromosikan produk-produk yang kurang diminati dengan membuat inovasi baru terhadap produk.

# %% [markdown]
# ### Bagaimana penjualan dan Revenue Produk dalam beberapa bulan terakhir?

# %% [markdown]
# Banyak nya produk yang di approved atau disetujui untuk order dan revenue per bulan cenderung stabil dibulan januari hingga mei, penjualan dan revenue mengalami sedikit penurunan saat bulan juni hingga juli, namun dapat naik kembali di bulan agustus. Meskipun naik, penurunan drastis dialami dibulan september, namun kembali naik lagi di bulan oktober. Puncak kenaikan ada pada bulan November, dan mengalami sedikit penurunan di bulan Desember.
# Dengan adanya visualisasi ini, pihak e-commerce akan mengetahui bagaimana revenue yang dimiliki per-bulan, oleh karena itu disarankan untuk memberbaiki sistem approved order agar mampu mengoptimalkan transaksi.

# %% [markdown]
# ### Bagaimana Demografis Customer yang Dimiliki?

# %% [markdown]
# Cusomer di dominasi dari Negara SP dengan 40000 lebih customer. Sedangkan untuk di Negara RR, AP, AC, customer masih terbilang sedikit jika dibandingkan dengan negara lain.
# Customer di kota sao paulo sangatlah banyak, adanya kesenjangan antara kota sao paulo dengan 4 kota dibawahnya menunjukkan bahwa customer tidak terlalu merata dan masih di dominasi oleh satu kota.
# untuk itu diharapkan e-commerce mampu mengembangkan bisnisnya lebih luas lagi dengan mengadakan promosi di beberapa Negara dan memaksimalkan di kota.

# %% [markdown]
# ### Seller kota mana yang menjual produk paling banyak?

# %% [markdown]
# Visualisasi ini menggambarkan top 5 dari seller city atau kota penjual dengan value penjualan terbanyak. Kota Sao Paulo adalah kota dengan penjualan terbanyak, oleh karena itu, dengan adanya grafik analisa ini sebagai bentuk untuk menunjang penjualan di daerah-daerah yang menjadi target dari e-commerce selain itu, hal ini dapat digunakan sebagai pemanfaatan penunjang kebutuhan bisnis agar selalu maju.
